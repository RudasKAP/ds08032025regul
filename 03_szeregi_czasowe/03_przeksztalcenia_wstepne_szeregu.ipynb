# %% [markdown]
# # Przekształcenia wstępne szeregu

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

#from google.colab import files
#src = list(files.upload().values())[0]
#open('ts_utils.py','wb').write(src)

#from ts_utils import check_time_series_stationary
from statsmodels.graphics.tsaplots import plot_acf

# %%
#funkcja do badania stacjonarności
from statsmodels.tsa.stattools import adfuller
def check_time_series_stationary(y, rolling_len = 12):
    
    y = pd.Series(y)
    
    df_test = adfuller(y)
    
    if df_test[1] < 0.05:
        print('Szereg jest stacjonarny')
    else:
        print('Szereg jest niestacjonarny')
    
    print("{0:^32s}".format("Dickey-Fuller Test"))
    print("-"*32+"\n")
    
    print("{0:<20s}: {1:>10.4f}".format('Test Statistic', df_test[0]))
    print("{0:<20s}: {1:>10.4f}".format('p-value', df_test[1]))
    print("-"*32+"\n")
    
    rolling_mean = y.rolling(rolling_len).mean()
    rolling_var = y.rolling(rolling_len).var()

    plt.plot(y)
    plt.plot(rolling_mean, label="Rolling mean")
    plt.plot(rolling_var, label="Rolling var")
    plt.legend()
    plt.show()
    
    print("{0:^32s}".format("Autocorrelation plot"))
    print("-"*32+"\n")
    pd.plotting.autocorrelation_plot(y)
    plt.show()

# %% [markdown]
# Chcemy umieć odwzorować zmiany w szeregu za pomocą modeli. Najłatwiej jest zamodelować szeregi stacjonarne. Tak więc przed przystąpieniem do analizy i prognozowania szeregów powinniśmy odpowiednio przygotować nasze dane.
#
# Przy użyciu określonych przekształceń, możemy
# - wyeliminować z szeregu składowe zmienności,
# - ułatwić identyfikację regularnych tendencji.

# %% [markdown]
# ## Transformacja logarytmiczna
#
# Jeśli w analizowanych danych dostrzegamy, że wariancja wzrasta lub maleje wraz z poziomem szeregu, przydatne może być zastosowanie transformacji logarytmicznej.
#
# Używająć logarytmu, możemy ustabilizować wariancję, a potem kontynuawać kolejne kroki analizy.
# Stabilizacja wariancji jest konieczna dla zastosowania modeli stacjonarnych.
#
# **Transformacja logarytmiczna/potęgowa danych przydatna jest między innymi w następujących przypadkach:**
# - występowanie wzrostu (lub spadku) amplitudy wahań sezonowych w kolejnych okresach,
# - niejednorodnej zmienności danych w kolejnych okresach,
# - dużego wpływu obserwacji odstających

# %%
air_passengers = pd.read_csv('AirPassengers.csv', parse_dates=['Month'], index_col='Month')

# %%
air_passengers.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
check_time_series_stationary(air_passengers['#Passengers'])
#problem: zdecydowanie nierówna wariancja
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :     0.8154
# p-value             :     0.9919
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
log_air_passengers = np.log(air_passengers)
check_time_series_stationary(log_air_passengers['#Passengers'])
#logarytm zrównał nam wariancje, ale dalej nie mamy stacjonarności
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -1.7170
# p-value             :     0.4224
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %% [markdown]
# ## Różnicowanie
#
# Operację różnicowania stosujemy między innymi w celu przekształcenia danych do postaci **stacjonarnej**.
#
# Róznicowanie sprowadza się do zastąpienia oryginalnych danych szeregiem różnic, wyznaczonych dla ustalonych opóźnień czasowych. Dobierając odpowiednio parametry różnicowania możemy wyeliminować z danych trend liniowy, kwadratowy, wielomianowy, a także sezonowość.

# %% [markdown]
# ### Róźnicowanie z opóźnieniem 1

# %% [markdown]
# Wczytaj dane `USGDP.csv` przedstawiające informację na temat kwartalnego produktu krajowego brutto w USA w latach 1947-2006, a następnie zastosuj różnicowanie z opóźnieniem 1 i sprawdź stacjonarność otrzymanego szeregu.

# %%
usgdp = pd.read_csv('USGDP.csv', 
                 parse_dates=['DATE'], index_col='DATE')

usgdp.head()
# Out:
#                GDPC1
# DATE
# 1947-01-01  2033.061
# 1947-04-01  2027.639
# 1947-07-01  2023.452
# 1947-10-01  2055.103
# 1948-01-01  2086.017

# %%
check_time_series_stationary(usgdp.GDPC1)
#jest trend i wariancja skacze i przede wszystkim rośnie
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :     2.9819
# p-value             :     1.0000
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
log_usgdp = np.log(usgdp)

# %%
check_time_series_stationary(log_usgdp.GDPC1)
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -2.1605
# p-value             :     0.2209
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
log_usgdp_diff = log_usgdp.diff(1)
log_usgdp_diff
#zamiast rozpatrywać szereg log Y_t, będziemy rozważać log Y_t-log Y_{t-1}
# Out:
#                GDPC1
# DATE
# 1947-01-01       NaN
# 1947-04-01 -0.002670
# 1947-07-01 -0.002067
# 1947-10-01  0.015521
# 1948-01-01  0.014931
# ...              ...
# 2018-07-01  0.007210
# 2018-10-01  0.002710
# 2019-01-01  0.007623
# 2019-04-01  0.004985
# 2019-07-01  0.005254
#
# [291 rows x 1 columns]

# %%
check_time_series_stationary(log_usgdp_diff.GDPC1.dropna())
#zdecydowanie doprowadziliśmy do stacjonarności
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -8.4548
# p-value             :     0.0000
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %% [markdown]
# ### Róźnicowanie z opóźnieniem sezonowym
#
# Różnicowanie szeregu zawierające dwie składowe systematyczne -- trend i sezonowość.

# %%
#wróćmy do zlogarytmizowanego we wcześniejszym zadaniu szeregu airpassengers
#jak pamiętamy ma on trend, pozbywamy się go różnicując
diff_log_air_passengers = log_air_passengers.diff()
check_time_series_stationary(diff_log_air_passengers['#Passengers'].dropna())
#jest sezonowość
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -2.7171
# p-value             :     0.0711
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
#sezonowość wyeliminujemy przez różnicowanie o okres
diff_log_air_passengers_diff12 = diff_log_air_passengers.diff(12)
diff_log_air_passengers_diff12.head(14)
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# 1949-06-01          NaN
# 1949-07-01          NaN
# 1949-08-01          NaN
# 1949-09-01          NaN
# 1949-10-01          NaN
# 1949-11-01          NaN
# 1949-12-01          NaN
# 1950-01-01          NaN
# 1950-02-01     0.039164

# %%
check_time_series_stationary(diff_log_air_passengers_diff12['#Passengers'].dropna())
#szereg stał się stacjonarny
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -4.4433
# p-value             :     0.0002
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %% [markdown]
# ## Zadanie - `co2`
#
# Wczytaj dane `co2_interpolated.csv` wskazujące stężenie CO2 w atmosferze (więcej pod [linkiem](https://datahub.io/core/co2-ppm)). Następnie korzystając z powyższych metod, spróbuj doprowadzić szereg do postaci stacjonarnej.

# %%
co2 = pd.read_csv('co2_interpolated.csv', parse_dates=['Date'], index_col='Date')
co2.head()
# Out:
#                CO2
# Date
# 1958-03-01  315.71
# 1958-04-01  317.45
# 1958-05-01  317.50
# 1958-06-01  317.10
# 1958-07-01  315.86

# %%
plt.plot(co2) #sezonowość i trend

# %%
check_time_series_stationary(co2.CO2) #oczywiście nie ma stacjonarności
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :     4.7749
# p-value             :     1.0000
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
co2_diff = co2.diff()
check_time_series_stationary(co2_diff.CO2.dropna()) #brak trendu, średnia i wariancja ruchome są stabilne, ale jest sezonowość
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -5.2874
# p-value             :     0.0000
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
co2_diff_diff12 = co2_diff.diff(12) #róznicujemy o okres i mamy szereg stacjonarny
check_time_series_stationary(co2_diff_diff12.CO2.dropna())
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :   -10.8713
# p-value             :     0.0000
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %% [markdown]
# ## Zadanie - `a10`
# Wczytaj dane ` a10.csv` opisujące miesięczną sprzedaż leków przeciwcukrzycowych w Australii w latach 1992–2008. Następnie korzystając z powyższych metod, spróbuj doprowadzić szereg do postaci stacjonarnej.

# %%
a10 = pd.read_csv('a10.csv', parse_dates=['date'], index_col='date')
a10.plot(legend=False)
# Out:
# <Axes: xlabel='date'>

# %%
check_time_series_stationary(a10.value)
#wariancja nie jest równa
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :     3.1452
# p-value             :     1.0000
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
log_a10 = np.log(a10)
check_time_series_stationary(log_a10.value)
#dzięki logarytmizacji pozbywamy się nierównych wariancji
# Out:
# Szereg jest niestacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -0.9887
# p-value             :     0.7574
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
log_a10_diff = log_a10.diff() #usuwamy trend
check_time_series_stationary(log_a10_diff.value.dropna())
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -4.5194
# p-value             :     0.0002
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
log_a10_diff_diff12 = log_a10_diff.diff(12) #usuwamy sezon i szereg jest stacjonarny
check_time_series_stationary(log_a10_diff_diff12.value.dropna())
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -4.7855
# p-value             :     0.0001
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %% [markdown]
# ## Zadanie - `daily-min-temperatures`
# Wczytaj dane `daily-min-temperatures.csv` opisujący minimalne dzienne temperatury w ciągu 10 lat (1981-1990) w Melbourne w Australii. Następnie korzystając z powyższych metod, spróbuj doprowadzić szereg do postaci stacjonarnej.

# %%
daily_temp = pd.read_csv('daily-min-temperatures.csv', 
                 parse_dates=['Date'], index_col='Date')

# %%
check_time_series_stationary(daily_temp.Temp) #sezonowość
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -4.4448
# p-value             :     0.0002
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %%
daily_temp_diff365 = daily_temp.diff(365) #usuwamy sezon i szereg jest stacjonarny
check_time_series_stationary(daily_temp_diff365.Temp.dropna())
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :   -19.0365
# p-value             :     0.0000
# --------------------------------
#       Autocorrelation plot
# --------------------------------

# %% [markdown]
# ## Zadanie - `daily-total-female-births`
# Wczytaj dane `daily-total-female-births.csv` przedstawiające całkowitą liczbę urodzeń kobiet zarejestrowanych w Kalifornii w USA w 1959 roku. Następnie korzystając z powyższych metod, spróbuj doprowadzić szereg do postaci stacjonarnej.

# %%
daily_birth = pd.read_csv('daily-total-female-births.csv', 
                 parse_dates=['Date'], index_col='Date')
daily_birth.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
check_time_series_stationary(daily_birth.Births) #jest stacjonarny nie trzeba żadnych przekształceń
# Out:
# Szereg jest stacjonarny
#        Dickey-Fuller Test
# --------------------------------
#
# Test Statistic      :    -4.8083
# p-value             :     0.0001
# --------------------------------
#       Autocorrelation plot
# --------------------------------
